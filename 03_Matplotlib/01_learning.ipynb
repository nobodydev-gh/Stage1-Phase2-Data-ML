# %%
import matplotlib.pyplot as plt
import numpy as np


fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4], [424,23,4344,31])  # Plot some data on the Axes.
plt.show()                           # Show the figure.

# %%
fig = plt.figure() 

 # an empty figure with no Axes

# %%
fig, ax = plt.subplots()
 # a figure with a single Axes

# %%
fig, axs = plt.subplots(2,2)
# a figure with a 2x2 grid of Axes

# %%
# a figure with one Axes on the left, and two Axes on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],['left', 'right_bottom']])

# %%
#Exploring

fig, ax = plt.subplots()

ax.grid(visible=False)


plt.title("Axis")
plt.ylabel("Y Axis")
plt.xlabel("X Axis")
# Out:
# Text(0.5, 0, 'X Axis')

# %%
b = np.matrix([[1, 2], [3, 4]])   #matrix 
b_asarray = np.asarray(b)           #converting to array

# %%
# np.random.seed(11)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c',s='d',  data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# The code creates a dictionary called data with 50 points for four different attributes:
#
#     a (X-axis): A simple sequence of numbers from 0 to 49 (0,1,2,…,49).
#
#     b (Y-axis): Based on a, but with added "noise" (random fluctuations). This ensures a linear trend exists but isn't a perfect straight line.
#
#     c (Color): 50 random integers between 0 and 50. These will be mapped to different colors using a colormap.
#
#     d (Size): Random numbers from a normal distribution, converted to absolute values and scaled by 100. This determines how big each "dot" on the plot will be.
