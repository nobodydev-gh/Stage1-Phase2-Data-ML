# %% [markdown]
# ## PHASE 3 #

# %% [markdown]
# Advanced operation and business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("==== Zomato sales analysis ==== ")
print("\n Sales data shape", sales_data.shape)
print("\n Sample data for 1st 3 restau: ", sales_data[:3])
# Out:
# ==== Zomato sales analysis ====
#
#  Sales data shape (5, 5)
#
#  Sample data for 1st 3 restau:  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
#total sales  per year
print(np.sum(sales_data,axis=0))
yearly_total = np.sum(sales_data[:,1:],axis=1)
print(yearly_total)




#min_sales per restaurant

min_sales = np.min(sales_data[:,1:], axis=1)
print(min_sales)



#Max sales per year of all

max_sales = np.max(sales_data[:,1:],axis=0)
print(max_sales)


#Averages sales per restaurant
avg_sales = np.mean(sales_data[:,1:], axis = 1)
print(avg_sales)
# Out:
# [     15  810000  945000 1085000 1240000]
# [800000 610000 990000 900000 780000]
# [150000 120000 200000 180000 160000]
# [200000 230000 260000 300000]
# [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:,1:], axis = 1 )
print(cumsum)
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.mean(sales_data[:3], axis=0))
plt.title("Average cummulative sales across all restaurants ")
plt.xlabel("Years")
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
## Vector operations

vect1 = np.array([1,2,3,4,5])
vect2 = np.array([6,7,8,9,10])

print("Vector addition: ",vect1 + vect2)



# vector multiplication 

print("Multipication: ",vect1 * vect2)



## DOT product

print("DOt product: ",np.dot(vect1,vect2))


print('\n')
# Out:
# Vector addition:  [ 7  9 11 13 15]
# Multipication:  [ 6 14 24 36 50]
# DOt product:  130
#
#
# 0.26554161733900966

# %%
vect1 = np.array([[1,2],[3,4]])
vect2 = np.array([[5,6],[7,8]])

print("Vector addition: ",vect1 + vect2)
# Out:
# Vector addition:  [[ 6  8]
#  [10 12]]

# %%
#Find angle

angle = np.arccos(np.dot(vect1,vect2) / (np.linalg.norm(vect1) * np.linalg.norm(vect2)))

print(angle)
# Out:
# 0.26554161733900966

# %%
types = np.array(['pen','ball','sharpner','pencil','eraser'])

vectorized_upper = np.vectorize(str.upper)
print(vectorized_upper(types))



##Broadcast
# Out:
# ['PEN' 'BALL' 'SHARPNER' 'PENCIL' 'ERASER']
